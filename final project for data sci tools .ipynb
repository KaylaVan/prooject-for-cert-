# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
#   **Kayla Van Namee**
#
#    robotics

# %% [markdown]
# *I am interested in data science because I enjoy robotics and want to learn how to program them to do great things for healthcare and autonomous vehicles*

# %% [markdown]
# ### my code is a simple calculator application

# %%
class calc():
    def __init__(self,a,b):
        self.a = a
        self.b = b
    def add(self):
        return self.a + self.b
    def sub(self):
        return self.a - self.b
    def multiply(self):
        return self.a * self.b
    def divide(self):
        return self.a / self.b

a = int(input('Enter First number : '))
b = int(input('Enter Second number : '))        
obj=calc(a,b)
while True:
    def menu():
        x = ('1. Add \n2. Sub \n3. Multiply \n4. Divide') 
        print(x)
    menu()
    choice = int(input('Please select one of the following : ')) 
    if choice == 1:
        print("Result: ",obj.add())
    elif choice == 2:
        print("Result: ",obj.sub())
    elif choice == 3:
        print("Result: ",obj.multiply())    
    elif choice == 4:
        print("Result: ",obj.divide())
    elif choice == 0:
        print('Again try one of the following')
        break
    else:
        print('Invalid option') 
        break       
print()
# Out:
# Enter First number : 45
# Enter Second number : 34
# 1. Add
# 2. Sub
# 3. Multiply
# 4. Divide
# Please select one of the following : 2
# Result:  11
# 1. Add
# 2. Sub
# 3. Multiply
# 4. Divide
# Please select one of the following : 0
# Again try one of the following

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```python
# s = "Python syntax highlighting"
# print s
# ```
#
# <a href="https://www.youtube.com/watch?v=lhYBX9aoIdY
# " target="_blank"><img src="https://www.youtube.com/watch?v=lhYBX9aoIdY"
# alt="IMAGE ALT TEXT HERE" width="240" height="180" border="10" /></a>
